# %% [markdown]
# In this assignment you are asked to analyze the complete weather dataset.
#
#
# ### Possible directions, from the general to the specific ###
# The following questions are meant as starting points, you are encouraged to go beyond them.
# Remember to describe your work, with words and figures, so that your reviewers, and anybody else, would be able to follow.

# %% [markdown]
# ### Coverage and Cleanup ###
# While the weather data collection is large, its coverage is very uneven. Many active stations exist in the USA and in India, while there are relatively very few in Africa.
#
# In this section our goal is to characterize the coverage of the data and to clean it based on the coverage.
# By *coverage* we mean to identify the geographic locations, times and types of measurements for which we have a lot of data and
# the parts for which we have only little. By establishing the coverage we identify the types of statistical queries that we can make and the types for which we have too little data.
#
# **Heirarchical representation:** When we want to represent sparse data, it is often useful to create a hierarchy:
#
# 1. **Can we ignore stations with no temperature recordings?** It seems reasonable to assume that any station that has published useful measurements has at least published minimum and maximum termperatures. Can you confirm or deny this?
# 1. **Geographic baseline:** Some parts of the world have a lot of stations and measurements, some very few. Create a hierarchical representation of this data.
# 1. **Measurement Types ** There is a large number of measurements, but most of them occur only rarely. Can you compute and describe:
#   1. How many times does each type of measurement occur in the database.
#   1. What fraction of the entries are not empty?

# %% [markdown]
# ### Collect statistics about the stations, choose a quantity "count" to represent the number of measurements available from each station.

# %%
import pandas as pd
import numpy as np
import sklearn as sk
print 'pandas version: ',pd.__version__
print 'numpy version:',np.__version__
print 'sklearn version:',sk.__version__
# Out:
# pandas version:  0.13.1
# numpy version: 1.8.1
# sklearn version: 0.14.1

# %%
import sys
home_dir='/home/ubuntu/UCSD_BigData'
sys.path.append(home_dir+'/utils')
from find_waiting_flow import *
from AWS_keypair_management import *

# %%
import pickle
Creds= pickle.load(open('/home/ubuntu/Vault/Creds.pkl','rb'))
print Creds.keys()
print Creds['mrjob'].keys()
pair=Creds['mrjob']
key_id=pair['key_id']
secret_key=pair['secret_key']
ID=pair['ID']
print ID,key_id
# Out:
# ['launcher', 'mrjob']
# ['key_id', 'secret_key', 's3_logs', 'ID', 's3_scratch']
# lojin AKIAIQXWOHH25RD7PZ7A

# %%
#job_flow_id=find_waiting_flow(key_id, secret_key)
job_flow_id
#job_flow_id=u'j-LTOJMJ14G840'
#job_flow_id=u'j-2KCJE554SGITB'
job_flow_id=u'j-6T8VIKMY8RHX'
#job_flow_id=u'j-2EFV3O64LF1U2'

# %%
data_dir=home_dir+'/data/weather'
# !ls $data_dir
# Out:
# ALL.head.csv	  ghcnd-stations_buffered.txt  Partition_Tree.pkl      Statistics.pkl.gz
# data-source.txt   ghcnd-stations.txt	       SAMPLE_TMAX.csv
# ghcnd-readme.txt  ghcnd-version.txt	       SAMPLE_TMAX.csv.old.gz

# %%
# !cat $data_dir/ALL.head.csv

# %%
a = (('TMAX',2),('TMIN',4))
sort(a, 1)
c = (('TMIN',5),('TMAX',4))
sort(c, 1)
b = zip(*a)
print b

d = zip(*c)
print d

print len(a)
print a[0][1]


if len(counts) == 2:
            if counts[0][0] == 'TMAX':
                yield(station, (counts[0][1], counts[1][1]))
            else:
                yield(station, (counts[1][1], counts[0][1]))
# Out:
# [('TMAX', 'TMIN'), (2, 4)]
# [('TMIN', 'TMAX'), (5, 4)]
# 2
# 2

# %%
# %%writefile count_cdf.py
#!/usr/bin/python
"""
count the number of measurement for each year
"""
import sys
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
import re
from sys import stderr
import re,pickle,base64,zlib

class MRWeather(MRJob):

    def mapper(self, _, line):
        try:
            self.increment_counter('MrJob Counters','mapper-all',1)
            elements=line.split(',')
            if elements[1] == 'TMAX' or elements[1] == 'TMIN':
                number_defined=sum([e!='' for e in elements[3:]])
                out = ((elements[1], number_defined), 1)
                yield out
        except Exception, e:
            stderr.write('Error in line:\n'+line)
            stderr.write(e)
            self.increment_counter('MrJob Counters','mapper-error',1)
            out=('error',(1,1))
        #finally:
        #    yield out
                
    def combiner(self, station, counts):
        self.increment_counter('MrJob Counters','combiner',1)
        yield (station, sum(counts))
    
    def reducer(self, station, counts):
        self.increment_counter('MrJob Counters','combiner',1)
        yield (station, sum(counts))

if __name__ == '__main__':
    MRWeather.run()
# Out:
# Overwriting count_cdf.py

# %%
# %%writefile calc_cdf.py
#!/usr/bin/python
"""
count the number of measurement for each year
"""
import sys
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
import re
from sys import stderr
import re,pickle,base64,zlib

class MRWeather(MRJob):

    def mapper(self, _, line):
        try:
            self.increment_counter('MrJob Counters','mapper-all',1)
            elements=line.split(',')
            if elements[1] == 'TMAX':
                number_defined=sum([e!='' for e in elements[3:]])
                out=((elements[0], elements[2]), (elements[1], number_defined))
                yield out
            if elements[1] == 'TMIN':
                number_defined=sum([e!='' for e in elements[3:]])
                out=((elements[0], elements[2]), (elements[1], number_defined))
                yield out
        except Exception, e:
            stderr.write('Error in line:\n'+line)
            stderr.write(e)
            self.increment_counter('MrJob Counters','mapper-error',1)
            out=('error',(1,1))
        #finally:
        #    yield out
    
    def reducer(self, station, counts):
        self.increment_counter('MrJob Counters','reducer',1)
        count = list(counts)
        if len(count) == 2:
            if count[0][0] == 'TMAX':
                yield(station, (count[0][1], count[1][1]))
            else:
                yield(station, (count[1][1], count[0][1]))
                
                
if __name__ == '__main__':
    MRWeather.run()
# Out:
# Overwriting calc_cdf.py

# %%
# %%writefile test.py
#!/usr/bin/python
"""
count the number of measurement for each year
"""
import sys
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
import re
from sys import stderr
import re,pickle,base64,zlib

class MRWeather(MRJob):

    def mapper(self, _, line):
        self.increment_counter('MrJob Counters','mapper-all',1)
        elements=line.split(',')
        out=(elements[0], 1)
        yield out
    
    def reducer(self, station, counts):
        self.increment_counter('MrJob Counters','reducer',1)
        yield(station, sum(counts))
                
if __name__ == '__main__':
    MRWeather.run()
# Out:
# Overwriting test.py

# %%
# !python calc_cdf.py -r emr --emr-job-flow-id $job_flow_id $data_dir/ALL.head.csv --output-dir=s3://lojin/Weather/data.csv  --no-output
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# Attempting to terminate job...
# Traceback (most recent call last):
#   File "calc_cdf.py", line 43, in <module>
#     MRWeather.run()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/job.py", line 494, in run
#     mr_job.execute()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/job.py", line 512, in execute
#     super(MRJob, self).execute()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/launch.py", line 147, in execute
#     self.run_job()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/launch.py", line 213, in run_job
#     self.stdout.flush()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/runner.py", line 614, in __exit__
#     self.cleanup()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/emr.py", line 1010, in cleanup
#     super(EMRJobRunner, self).cleanup(mode=mode)
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/runner.py", line 560, in cleanup
#     self._cleanup_job()
# ...

# %%
# !python test.py -r emr --emr-job-flow-id $job_flow_id s3://lojin/Weather/data.csv > temp
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# Attempting to terminate job...
# Traceback (most recent call last):
#   File "test.py", line 25, in <module>
#     MRWeather.run()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/job.py", line 494, in run
#     mr_job.execute()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/job.py", line 512, in execute
#     super(MRJob, self).execute()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/launch.py", line 147, in execute
#     self.run_job()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/launch.py", line 213, in run_job
#     self.stdout.flush()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/runner.py", line 614, in __exit__
#     self.cleanup()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/emr.py", line 1010, in cleanup
#     super(EMRJobRunner, self).cleanup(mode=mode)
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/runner.py", line 560, in cleanup
#     self._cleanup_job()
# ...

# %%
# !cat Station_Count

# %%
# !python calc_cdf.py -r emr --emr-job-flow-id $job_flow_id hdfs:/weather/weather.csv > Station_Count
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/calc_cdf.ubuntu.20140525.214648.450815
# Copying non-input files into s3://lojin/scratch/calc_cdf.ubuntu.20140525.214648.450815/files/
# Adding our job to existing job flow j-2KCJE554SGITB
# Job launched 30.4s ago, status RUNNING: Running step (calc_cdf.ubuntu.20140525.214648.450815: Step 1 of 1)
# Job launched 60.6s ago, status RUNNING: Running step (calc_cdf.ubuntu.20140525.214648.450815: Step 1 of 1)

# %%
data_in=open('Station_Count', 'r')
tmax_cdf = [0] * 366
tmin_cdf = [0] * 366

for line in data_in.readlines():
    words=line.split('\t')
    words[1]=words[1].replace('[','')
    words[1]=words[1].replace(']','')
    wordss=words[1].split(',')
    tmax_cdf[int(wordss[0])] = tmax_cdf[int(wordss[0])] + 1
    tmin_cdf[int(wordss[1])] = tmin_cdf[int(wordss[1])] + 1

data_in.close()
tmax_cdf = np.cumsum(tmax_cdf)
tmin_cdf = np.cumsum(tmin_cdf)

plot(tmax_cdf)
plot(tmin_cdf)

# %%
data_in=open('Station_Count', 'r')

station_weight={}

for line in data_in.readlines():
    words=line.split('\t')
    station_name=words[0].split(',')
    station_name[0]=station_name[0].replace('"','')
    station_name[0]=station_name[0].replace('[','')
    
    weight=words[1].split(',')
    weight[0]=weight[0].replace('[','')
    weight[1]=weight[1].replace(']','')
    
    if weight[0] >= 350 and weight[1] >= 350:
        if station_weight.get(station_name[0]):
            station_weight[station_name[0]] = station_weight[station_name[0]] + int(weight[0]) + int(weight[1])
        else:
            station_weight[station_name[0]] = int(weight[0]) + int(weight[1])

print station_weight
# Out:
# {'CA004035200': 15989, 'USS0006H19S': 17388, 'USC00390043': 82252, 'USC00043392': 7843, 'USC00163800': 83257, 'USC00043397': 34142, 'CA004012400': 49689, 'USC00235207': 34444, 'CA006059D09': 26356, 'USC00418845': 19830, 'AR000087129': 39248, 'USC00514091': 17795, 'CA003023665': 8322, 'USC00485055': 53164, 'RSM00022573': 9971, 'USC00452126': 1552, 'CA006079415': 35935, 'GQC00914120': 158, 'USR0000TLGR': 8076, 'GLE00100992': 14176, 'USC00441999': 1543, 'USC00485581': 7123, 'USS0009D06S': 21848, 'USC00346756': 2006, 'USC00519340': 2, 'SW000002080': 34978, 'USC00468730': 4242, 'USW00024239': 27014, 'CA006110270': 24283, 'SG000061687': 22918, 'NOE00111102': 4340, 'USW00024231': 36783, 'USW00024230': 45558, 'USW00024233': 47466, 'USC00248324': 46522, 'USC00404673': 34197, 'USW00024234': 23207, 'USW00024237': 46588, 'USW00024236': 516, 'USC00475469': 842, 'USC00041534': 21967, 'USC00107563': 8652, 'ASN00099015': 931, 'USS0005J37S': 16844, 'USC00163807': 12825, 'SW000002550': 33826, 'IN01202
# ...

# %%
data_in=open('data_for_analysis.csv', 'r')

data_in.read()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-313-eadf2c3bbd36> in <module>()
#       1 data_in=open('data_for_analysis.csv', 'r')
#       2
# ----> 3 data_in.read()
#
# MemoryError:

# %%
D_weight=pd.DataFrame((station_weight.items()), columns=['station', 'weight'])
D_weight.head()
Djoined=D_weight.join(stations,on='station')
Djoined.head()
print len(Djoined)
Djoined.head()
Djoined=Djoined.drop('WMOID', 1)
Djoined=Djoined.drop('HCNFLAG', 1)
Djoined=Djoined.drop('GSNFLAG', 1)
Djoined=Djoined.drop('name', 1)
Djoined=Djoined.drop('state', 1)
Djoined=Djoined.drop('elevation', 1)
Djoined.head()
# Out:
# 29065
#        station  weight  latitude  longitude
# 0  CA004035200   15989   49.1700  -104.5800
# 1  USS0006H19S   17388   41.3333  -106.5000
# 2  USC00390043   82252   43.4892   -99.0631
# 3  USC00043392    7843   34.0869  -118.4794
# 4  USC00163800   83257   30.4192   -92.0439
#
# [5 rows x 4 columns]

# %%
import pandas as pd

class HierarchicalPartion(object):

	def __init__(self, df, levels):
		self.levels = levels
		self.df = df

	def get_id(self, bits):
		return sum(bit * (2**i) for bit, i in zip(bits, range(len(bits))))

	def get_partition(self, partition):
		if partition == 'latitude':
			return 'longitude'
		return 'latitude'

	def execute(self, df, level, partition='latitude', N=90, S=-90, W=-180, E=180, bits=[]):
		if level <= 0:
			id = self.get_id(bits)
			df['id'] = id
			region = {'id': id,
			          'N': N, 'S': S, 'W': W, 'E': E,
			          'weight': df.weight.sum()}
			return df, region

		df = df.sort(partition)
		df['cumulative_weight'] = df.weight.cumsum()
		threshold = df.weight.sum()/2
		tree_id = 'tree' + str(level)
		df[tree_id] = df.cumulative_weight > threshold
		del df['cumulative_weight']
		grouped_df = df.groupby(tree_id)

		group_below_threshold = pd.DataFrame()
		group_above_threshold = pd.DataFrame()
		for flag, group in grouped_df:
			if flag: group_above_threshold = group
			else: group_below_threshold = group

		min_Value = group_above_threshold[partition].min()
		max_Value = group_below_threshold[partition].max()

		border = (max_Value + min_Value)/2

		children_df = []
		children_leaves = []

		for flag, child in grouped_df:
			if partition == 'latitude':
				if flag:
					S = border
				else:
					N = border
			else:
				if flag:
					W = border
				else:
					E = border
			child_df, child_leaves = self.execute(child,
			                                      level-1,
			                                      self.get_partition(partition),
			                                      N, S, W, E,
			                                      [flag]+bits)
			children_df.append(child_df)
			children_leaves.append(child_leaves)

		return pd.concat(children_df), children_leaves

# %%
hp = HierarchicalPartion(Djoined, 10)
res, res2 = hp.execute(Djoined, 10)

# %%
res.head()
#res.tail()
#print type(res)
# Out:
#            station  weight  latitude  longitude tree10  tree9  tree8  tree7  \
# 12416  FJ000091652     516  -16.1330  -179.9830  False  False  False  False
# 17152  AYW00068701     518  -80.0167  -178.4167  False  False  False  False
# 4234   NZ000093994   47890  -29.2500  -177.9170  False  False  False  False
# 886    NZ000939870   34941  -43.9500  -176.5670  False  False  False  False
# 24807  WF000917530   27188  -13.2330  -176.1670  False  False  False  False
#
#        tree6  tree5  tree4  tree3  tree2  tree1  id
# 12416  False  False  False  False  False  False   0
# 17152  False  False  False  False  False  False   0
# 4234   False  False  False  False  False  False   0
# 886    False  False  False  False  False  False   0
# 24807  False  False  False  False  False  False   0
#
# [5 rows x 15 columns]

# %%
res.ix[12416]['station']
res.ix[0]['id']
# Out:
# 719

# %%
a = {}
#a={[CA004035200, 719]}
a[abc] = 10
print a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-349-40d413b84307> in <module>()
#       1 a = {}
#       2 #a={[CA004035200, 719]}
# ----> 3 a[abc] = 10
#       4 print a
#
# TypeError: unhashable type: 'list'

# %%
for index in range(0, 1024):
    print str('station_id[')+str('\'')+str(res.ix[index]['station'])+str('\'')+']='+ str(res.ix[index]['id'])
# Out:
# station_id['CA004035200']=719
# station_id['USS0006H19S']=576
# station_id['USC00390043']=591
# station_id['USC00043392']=34
# station_id['USC00163800']=92
# station_id['USC00043397']=133
# station_id['CA004012400']=730
# station_id['USC00235207']=213
# station_id['CA006059D09']=907
# station_id['USC00418845']=73
# station_id['AR000087129']=272
# station_id['USC00514091']=6
# station_id['CA003023665']=739
# station_id['USC00485055']=587
# station_id['RSM00022573']=1004
# station_id['USC00452126']=640
# station_id['CA006079415']=907
# station_id['GQC00914120']=382
# station_id['USR0000TLGR']=77
# station_id['GLE00100992']=942
# station_id['USC00441999']=456
# station_id['USC00485581']=587
# station_id['USS0009D06S']=610
# station_id['USC00346756']=197
# station_id['USC00519340']=3
"""
count the number of measurement for each year
"""
import sys
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
import re
from sys import stderr

class MRWeather(MRJob):

    def mapper(self, _, line):
        self.increment_counter('MrJob Counters','mapper-all',1)
        elements=line.split('\t')
        #word_1=elements[0].split[',']
        #word_11=word_1[0].replace('[', '')
        #word_11=word11.replace('\"', '')
        #word_11=word11.replace('"', '')
        #word_11=word11.replace('\\', '')
        out=(elements[0], 1)
        yield out
    
    def reducer(self, station, counts):
        self.increment_counter('MrJob Counters','reducer',1)
        yield(station, sum(counts))
                
if __name__ == '__main__':
    MRWeather.run()
# Out:
# Overwriting test.py

# %%
# !python test.py -r emr --emr-job-flow-id $job_flow_id s3://lojin/scratch/test.ubuntu.20140526.052957.147244/files/data_for_analysis.csv > Testtttt
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/test.ubuntu.20140526.060443.038455
# Copying non-input files into s3://lojin/scratch/test.ubuntu.20140526.060443.038455/files/
# Adding our job to existing job flow j-6T8VIKMY8RHX
# Job launched 30.3s ago, status RUNNING: Running step (test.ubuntu.20140526.060443.038455: Step 1 of 1)
# Job launched 60.6s ago, status RUNNING: Running step (test.ubuntu.20140526.060443.038455: Step 1 of 1)
# Job launched 90.9s ago, status RUNNING: Running step (test.ubuntu.20140526.060443.038455: Step 1 of 1)
# Job completed.
# Running time was 97.0s (not counting time spent waiting for the EC2 instances)
# ec2_key_pair_file not specified, going to S3
# Fetching counters from S3...
# Waiting 5.0s for S3 eventual consistency
# Counters may not have been uploaded to S3 yet. Try again in 5 minutes with: mrjob fetch-logs --counters j-6T8VIKMY8RHX
# Counters from step 1:
#   (no counters found)
# ...

# %%
# !python test.py -r emr --emr-job-flow-id $job_flow_id s3://lojin/Weather/data_prepared.csv > Tesss
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/test.ubuntu.20140526.061409.574007
# Copying non-input files into s3://lojin/scratch/test.ubuntu.20140526.061409.574007/files/
# Adding our job to existing job flow j-6T8VIKMY8RHX
# Job launched 30.3s ago, status RUNNING: Running step
# Job launched 60.5s ago, status RUNNING: Running step
# Job launched 90.8s ago, status RUNNING: Running step
# Job launched 121.2s ago, status RUNNING: Running step
# Job launched 151.4s ago, status RUNNING: Running step
# Job launched 181.7s ago, status RUNNING: Running step
# Job launched 212.0s ago, status RUNNING: Running step
# Job launched 242.3s ago, status RUNNING: Running step
# Job launched 272.6s ago, status RUNNING: Running step
# Job launched 302.9s ago, status RUNNING: Running step
# Job launched 333.2s ago, status RUNNING: Running step
# Job launched 363.6s ago, status RUNNING: Running step
# Job launched 394.0s ago, status RUNNING: Running step
# ...

# %%
# !python test.py -r emr --emr-job-flow-id $job_flow_id data_for_analysis.csv > Test.out
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/test.ubuntu.20140526.052957.147244
# Copying non-input files into s3://lojin/scratch/test.ubuntu.20140526.052957.147244/files/
# Adding our job to existing job flow j-6T8VIKMY8RHX
# Job launched 30.2s ago, status RUNNING: Running step (test.ubuntu.20140526.052957.147244: Step 1 of 1)
# Job launched 60.4s ago, status RUNNING: Running step (test.ubuntu.20140526.052957.147244: Step 1 of 1)
# Job launched 90.7s ago, status RUNNING: Running step (test.ubuntu.20140526.052957.147244: Step 1 of 1)
# Job on job flow j-6T8VIKMY8RHX failed with status WAITING: Waiting after step failed
# Logs are in s3://yoav.hadoop/log/j-6T8VIKMY8RHX/
# ec2_key_pair_file not specified, going to S3
# Scanning S3 logs for probable cause of failure
# Waiting 5.0s for S3 eventual consistency
# Attempting to terminate job...
# Traceback (most recent call last):
#   File "test.py", line 1054, in <module>
#     MRWeather.run()
# ...

# %%
print station_id['USC00126164']
# Out:
# 429

# %%
data_in=open('CountCdf', 'r')
tmax_cdf = [0] * 366
tmin_cdf = [0] * 366

for line in data_in.readlines():
    words=line.split('\t')
    words[0]=words[0].replace('"','')
    words[0]=words[0].replace('[','')
    words[0]=words[0].replace(']','')
    words[0]=words[0].replace(' ','')
    wordss=words[0].split(',')
    if wordss[0] == 'TMAX':
        tmax_cdf[int(wordss[1])] = tmax_cdf[int(wordss[1])] + int(words[1])
    if wordss[0] == 'TMIN':
        tmin_cdf[int(wordss[1])] = tmin_cdf[int(wordss[1])] + int(words[1])

data_in.close()
tmax_cdf = np.cumsum(tmax_cdf)
tmin_cdf = np.cumsum(tmin_cdf)
#tmax_cdf = tmax_cdf/max(tmax_cdf)
#tmin_cdf = tmin_cdf/max(tmin_cdf)

plot(tmax_cdf)
plot(tmin_cdf)

# %%
# %%writefile calculate_weight.py
#!/usr/bin/python
"""
count the number of measurement for each year
"""
import sys
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
import re
from sys import stderr
import re,pickle,base64,zlib

threshold = 350

class MRWeather(MRJob):

    def mapper(self, _, line):
        try:
            self.increment_counter('MrJob Counters','mapper-all',1)
            elements=line.split(',')
            if elements[1] == 'TMAX' or elements[1] == 'TMIN':
                number_defined=sum([e!='' for e in elements[3:]])
                if number_defined >=  threshold:
                    out = (elements[0], number_defined)
                    yield out
        except Exception, e:
            self.increment_counter('MrJob Counters','mapper-error',1)
            stderr.write('Error in line:\n'+line)
            stderr.write(e)
            out=('error',(1,1))
                
    def combiner(self, station, counts):
        self.increment_counter('MrJob Counters','combiner',1)
        yield (station, sum(counts))
    
    def reducer(self, station, counts):
        self.increment_counter('MrJob Counters','combiner',1)
        yield (station, sum(counts))

if __name__ == '__main__':
    MRWeather.run()
# Out:
# Overwriting calculate_weight.py

# %%
# !python calculate_weight.py -r emr --emr-job-flow-id $job_flow_id hdfs:/weather/weather.csv > CalcWeight
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/calculate_weight.ubuntu.20140525.191103.824999
# Copying non-input files into s3://lojin/scratch/calculate_weight.ubuntu.20140525.191103.824999/files/
# Adding our job to existing job flow j-LTOJMJ14G840
# Job launched 30.3s ago, status RUNNING: Running step
# Job launched 60.6s ago, status RUNNING: Running step
# Job launched 90.8s ago, status RUNNING: Running step
# Job launched 121.1s ago, status RUNNING: Running step (calculate_weight.ubuntu.20140525.191103.824999: Step 1 of 1)
# Job launched 151.3s ago, status RUNNING: Running step (calculate_weight.ubuntu.20140525.191103.824999: Step 1 of 1)
# Job launched 181.6s ago, status RUNNING: Running step (calculate_weight.ubuntu.20140525.191103.824999: Step 1 of 1)
# Job launched 211.9s ago, status RUNNING: Running step (calculate_weight.ubuntu.20140525.191103.824999: Step 1 of 1)
# Job completed.
# ...

# %%
# !cat CalcWeight
# Out:
# "AQC00914873"	705
# "AR000087270"	28030
# "AR000087344"	30604
# "AR000087418"	28068
# "AR000087715"	30552
# "AR000087803"	26147
# "AR000870470"	32830
# "ASN00001019"	6499
# "ASN00002012"	42246
# "ASN00002056"	13198
# "ASN00003002"	36022
# "ASN00003057"	13742
# "ASN00003093"	8686
# "ASN00004083"	8679
# "ASN00005026"	38186
# "ASN00005051"	3943
# "ASN00005084"	1424
# "ASN00007017"	8601
# "ASN00007064"	3625
# "ASN00007185"	9412
# "ASN00007204"	723
# "ASN00007600"	7971
# "ASN00008249"	1440
# "ASN00008296"	5796
# "ASN00009514"	10905
# "ASN00009569"	8716
# "ASN00009572"	14176
# "ASN00009789"	30640
# "ASN00009877"	4322
# "ASN00009965"	10901
# "ASN00009998"	4991
# "ASN00010152"	8612
# "ASN00010592"	33999
# "ASN00010622"	29541
# "ASN00010633"	12476
# "ASN00010905"	7992
# "ASN00010916"	7983
# "ASN00012008"	5777
# "ASN00012022"	19600
# "ASN00012044"	6534
# "ASN00012239"	6495
# "ASN00012242"	7435
# "ASN00012305"	8342
# "ASN00013012"	25869
# "ASN00014277"	7174
# "ASN00014626"	25348
# ...

# %%
# %%writefile count_measurement.py
#!/usr/bin/python
"""
count the number of measurement for each year
"""
import sys
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
import re
from sys import stderr
import re,pickle,base64,zlib

class MRWeather(MRJob):

    def mapper(self, _, line):
        try:
            self.increment_counter('MrJob Counters','mapper-all',1)
            elements=line.split(',')
            out = (elements[0], number_defined)
        except Exception, e:
            stderr.write('Error in line:\n'+line)
            stderr.write(e)
            self.increment_counter('MrJob Counters','mapper-error',1)
            out=('error',(1,1))
        finally:
            yield out
                
    def combiner(self, station, counts):
        self.increment_counter('MrJob Counters','combiner',1)
        yield (word, sum(counts))
    
    def reducer(self, station, counts):
        self.increment_counter('MrJob Counters','combiner',1)
        yield (word, sum(counts))

if __name__ == '__main__':
    MRWeather.run()
# Out:
# Overwriting count_measurement.py

# %%
# !python count_measurement.py -r emr --emr-job-flow-id $job_flow_id $data_dir/ALL.head.csv > Counts
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/count_measurement.ubuntu.20140526.041306.961385
# Copying non-input files into s3://lojin/scratch/count_measurement.ubuntu.20140526.041306.961385/files/
# Adding our job to existing job flow j-LTOJMJ14G840
# Job launched 30.7s ago, status RUNNING: Running step (count_measurement.ubuntu.20140526.041306.961385: Step 1 of 1)
# Job launched 61.6s ago, status RUNNING: Running step (count_measurement.ubuntu.20140526.041306.961385: Step 1 of 1)
# Job launched 92.5s ago, status RUNNING: Running step (count_measurement.ubuntu.20140526.041306.961385: Step 1 of 1)
# Job on job flow j-LTOJMJ14G840 failed with status RUNNING: Running step
# Logs are in s3://yoav.hadoop/log/j-LTOJMJ14G840/
# ec2_key_pair_file not specified, going to S3
# Scanning S3 logs for probable cause of failure
# Waiting 5.0s for S3 eventual consistency
# Attempting to terminate job...
# Traceback (most recent call last):
# ...

# %%
# %%writefile select_max_min.py
#!/usr/bin/python
"""
count the number of measurement for each year
"""
import sys
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
import re
from sys import stderr
import re,pickle,base64,zlib

class MRWeather(MRJob):

    def mapper(self, _, line):
        try:
            self.increment_counter('MrJob Counters','mapper-all',1)
            elements=line.split(',')
            if elements[1] == 'TMAX':
                out=((elements[0], elements[2]), (elements[1], elements[3:]))
                yield out
            if elements[1] == 'TMIN':
                out=((elements[0], elements[2]), (elements[1], elements[3:]))
                yield out
        except Exception, e:
            stderr.write('Error in line:\n'+line)
            stderr.write(e)
            self.increment_counter('MrJob Counters','mapper-error',1)
            out=('error',(1,1))
        #finally:
        #    yield out
    
    def reducer(self, station, counts):
        self.increment_counter('MrJob Counters','reducer',1)
        count = list(counts)
        if len(count) == 2:
            if count[0][0] == 'TMAX':
                yield(station, (count[0][1] + count[1][1]))
            else:
                yield(station, (count[1][1] + count[0][1]))
                
                
if __name__ == '__main__':
    MRWeather.run()
# Out:
# Overwriting select_max_min.py

# %%
# !python select_max_min.py $data_dir/ALL.head.csv > Select_Max_Min
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/select_max_min.ubuntu.20140525.220706.248847
# writing to /tmp/select_max_min.ubuntu.20140525.220706.248847/step-0-mapper_part-00000
# Counters from step 1:
#   MrJob Counters:
#     mapper-all: 999
# writing to /tmp/select_max_min.ubuntu.20140525.220706.248847/step-0-mapper-sorted
# > sort /tmp/select_max_min.ubuntu.20140525.220706.248847/step-0-mapper_part-00000
# writing to /tmp/select_max_min.ubuntu.20140525.220706.248847/step-0-reducer_part-00000
# Counters from step 1:
#   MrJob Counters:
#     mapper-all: 999
#     reducer: 123
# Moving /tmp/select_max_min.ubuntu.20140525.220706.248847/step-0-reducer_part-00000 -> /tmp/select_max_min.ubuntu.20140525.220706.248847/output/part-00000
# Streaming final output from /tmp/select_max_min.ubuntu.20140525.220706.248847/output
# removing tmp directory /tmp/select_max_min.ubuntu.20140525.220706.248847

# %%
# !cat Select_Max_Min
# Out:
# ["MX000008172", "1928"]	["", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "210", "220", "240", "240", "210", "210", "270", "210", "200", "170", "153", "201", "193", "163", "135", "162", "202", "222", "193", "202", "224", "250", "253", "241", "243", "192", "111", "211", "222", "212", "231", "244", "251", "243", "234", "243", "184", "141", "211", "214", "244", "243", "242", "252", "213", "212", "204", "204", "193", "214", "224", "250", "171", "223", "254", "273", "230", "281", "261", "250", "262", "254", "233", "293", "182", "293", "282", "213", "192", "210", "241", "241", "290", "222", "254", "264", "251", "232", "224", "204", "243", "231", "271", "232", "263", "222", "264", "252", "273", "252", "21
# ...

# %%
data_in=open('Select_Max_Min', 'r')

for line in data_in.readlines():
    words=line.split('\t')
    words[1]=words[1].replace('1','')
    words[1]=words[1].replace('2','')
    words[1]=words[1].replace('3','')
    words[1]=words[1].replace('4','')
    words[1]=words[1].replace('5','')
    words[1]=words[1].replace('6','')
    words[1]=words[1].replace('7','')
    words[1]=words[1].replace('8','')
    words[1]=words[1].replace('9','')
    words[1]=words[1].replace('0','')
    words[1]=words[1].replace('-','')
    
    #print len(words[1])

# %%
# !python count_measurement.py hdfs:/weather/weather.csv > Counts
# Out:
#   File "count_measurement.py", line 21
#     else elements[1] == 'TMIN':
#                 ^
# SyntaxError: invalid syntax

# %%
# !cat counts

# %%
data_in=open('Counts', 'r')
data_out=open('Counts.csv', 'w')

for line in data_in.readlines():
    words=line.split('\t')
    words[0]=words[0].replace('"','')
    string=words[0]+','+words[1]
    data_out.write(string)
data_out.close()

header=['station','weight']
measurement_count = pd.read_csv('Counts.csv',header=None,names=header)

measurement_count.head()
# Out:
#        station  weight
# 0  AJ000037668   10014
# 1  AJ000037679    9800
# 2  AJ000037734   18856
# 3  AJ000037756   16319
# 4  AJ000037844   21929
#
# [5 rows x 2 columns]

# %%
data_out=open(data_dir+'/ghcnd-stations_buffered.txt','w')
for line in open(data_dir+'/ghcnd-stations.txt','r').readlines():
    line=line.rstrip()
    string=line+' '*(90-len(line))+'\n'
    data_out.write(string)
data_out.close()

colspecs = [(0, 11), (11, 21), (21, 31), (31, 38),(39,41),(41,72),(72,76),(76,80),(80,86)]
stations = pd.read_fwf(data_dir+'/ghcnd-stations_buffered.txt', colspecs=colspecs, header=None, index_col=0, names=['latitude','longitude','elevation','state','name','GSNFLAG','HCNFLAG','WMOID'])

stations.head()
# Out:
#              latitude  longitude  elevation state                   name  \
# ACW00011604   17.1167   -61.7833       10.1   NaN  ST JOHNS COOLIDGE FLD
# ACW00011647   17.1333   -61.7833       19.2   NaN               ST JOHNS
# AE000041196   25.3330    55.5170       34.0   NaN    SHARJAH INTER. AIRP
# AF000040930   35.3170    69.0170     3366.0   NaN           NORTH-SALANG
# AG000060390   36.7167     3.2500       24.0   NaN     ALGER-DAR EL BEIDA
#
#             GSNFLAG HCNFLAG  WMOID
# ACW00011604     NaN     NaN    NaN
# ACW00011647     NaN     NaN    NaN
# AE000041196     GSN     NaN  41196
# AF000040930     GSN     NaN  40930
# AG000060390     GSN     NaN  60390
#
# [5 rows x 8 columns]

# %%
Djoined=measurement_count.join(stations,on='station')
Djoined.head()
# Out:
#        station  weight  latitude  longitude  elevation state       name  \
# 0  AJ000037668   10014    41.100     47.500        583   NaN  VARTASHEN
# 1  AJ000037679    9800    41.100     49.200        -26   NaN    SIASAN'
# 2  AJ000037734   18856    40.800     46.000        404   NaN    SHAMHOR
# 3  AJ000037756   16319    40.533     48.933        755   NaN     MARAZA
# 4  AJ000037844   21929    40.333     48.167          4   NaN   KURDAMIR
#
#   GSNFLAG HCNFLAG  WMOID
# 0     NaN     NaN  37668
# 1     NaN     NaN  37679
# 2     NaN     NaN  37734
# 3     NaN     NaN  37756
# 4     NaN     NaN  37844
#
# [5 rows x 10 columns]

# %%
Djoined['log-weight']=log(Djoined['weight'].values)
Djoined.head()
# Out:
#        station  weight  latitude  longitude  elevation state       name  \
# 0  AJ000037668   10014    41.100     47.500        583   NaN  VARTASHEN
# 1  AJ000037679    9800    41.100     49.200        -26   NaN    SIASAN'
# 2  AJ000037734   18856    40.800     46.000        404   NaN    SHAMHOR
# 3  AJ000037756   16319    40.533     48.933        755   NaN     MARAZA
# 4  AJ000037844   21929    40.333     48.167          4   NaN   KURDAMIR
#
#   GSNFLAG HCNFLAG  WMOID  log-weight
# 0     NaN     NaN  37668    9.211739
# 1     NaN     NaN  37679    9.190138
# 2     NaN     NaN  37734    9.844586
# 3     NaN     NaN  37756    9.700085
# 4     NaN     NaN  37844    9.995565
#
# [5 rows x 11 columns]

# %%
from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt

lonmin=-180;lonmax=180;latsmin=-80;latsmax=80;
plt.figure(figsize=(15,10),dpi=300)
m = Basemap(projection='merc',llcrnrlat=latsmin,urcrnrlat=latsmax, llcrnrlon=lonmin,urcrnrlon=lonmax,lat_ts=20,resolution='i')
m.drawcoastlines()
m.fillcontinents(color='coral',lake_color='aqua')
parallels = np.arange(-80,81,10.)
meridians = np.arange(10.,351.,20.)
m.drawparallels(parallels,labels=[False,True,True,False])
m.drawmeridians(meridians,labels=[True,False,False,True])
m.drawmapboundary(fill_color='aqua')
x,y = m(Djoined['longitude'].tolist(),Djoined['latitude'].tolist())
m.colorbar(m.scatter(x,y,c=Djoined['weight'].tolist(),marker='.',zorder=15, s=5,lw=0),location='bottom',pad="5%")

plt.title('# of measurements')
plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(15,10),dpi=300)
m = Basemap(projection='merc',llcrnrlat=latsmin,urcrnrlat=latsmax, llcrnrlon=lonmin,urcrnrlon=lonmax,lat_ts=20,resolution='i')
m.drawcoastlines()
m.fillcontinents(color='coral',lake_color='aqua')
parallels = np.arange(-80,81,10.)
meridians = np.arange(10.,351.,20.)
m.drawparallels(parallels,labels=[False,True,True,False])
m.drawmeridians(meridians,labels=[True,False,False,True])
m.drawmapboundary(fill_color='aqua')
x,y = m(res['longitude'].tolist(),res['latitude'].tolist())
m.colorbar(m.scatter(x,y,c=res['id'].tolist(),marker='.',zorder=15, s=5,lw=0),location='bottom',pad="5%")

plt.title('# of measurements')
plt.show()

# %%
a = [0]*5
a[2] = 3
print a
# Out:
# [0, 0, 3, 0, 0]

# %%
print shape(x)
# Out:
# (85273,)

# %%
shape(x)
# Out:
# (85273,)

# %%
# !s3cmd ls s3://lojin
# Out:
#                        DIR   s3://lojin/log/
#                        DIR   s3://lojin/scratch/

# %%
partition_tree = pickle.load(open('/home/ubuntu/data/weather/Partition_Tree.pkl','rb'))

# %%
print partition_tree
# Out:
# {'Partition_Tree':         coord  counter         key  threshold  level
# 0    latitude      875   101100011    38.2875      9
# 1   longitude     1146  0001110001  -111.8997     10
# 2    latitude      603   001010011    31.1333      9
# 3   longitude      516    11111101    66.0500      8
# 4   longitude       78      001001  -100.2831      6
# 5    latitude      257     1111011    65.0072      7
# 6   longitude     1306  0100010001  -123.7531     10
# 7   longitude     1624  1001001111   -85.3089     10
# 8   longitude     1462  0110101101   -94.2167     10
# 9   longitude     1617  1001001000   -86.9064     10
# 10  longitude     1536  0111110111  -100.5700     10
# 11  longitude     1342  0100110101  -118.3000     10
# 12  longitude     1376  0101010111  -150.5833     10
# 13  longitude     1710  1010100101   141.6486     10
# 14   latitude      169     0100011    46.5833      7
# 15  longitude      513    11111010   128.6500      8
# ...

# %%
# !mrjob create-job-flow -c mr_bootstrap.conf
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/mrjob", line 17, in <module>
#     main()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/cmd.py", line 60, in main
#     commands[args[1]](args[2:])
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/cmd.py", line 78, in create_jf
#     main(args)
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/tools/emr/create_job_flow.py", line 39, in main
#     runner = EMRJobRunner(**runner_kwargs(args))
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/emr.py", line 568, in __init__
#     super(EMRJobRunner, self).__init__(**kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/runner.py", line 352, in __init__
#     self._opts = self.OPTION_STORE_CLASS(self.alias, opts, conf_paths)
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/emr.py", line 403, in __init__
#     super(EMRRunnerOptionStore, self).__init__(alias, opts, conf_path)
# ...

# %%
# !ls
# Out:
# Analysis.ipynb	      Counts.csv		       Select_Max_Min
# calc_cdf.py	      Counts.pkl		       select_max_min.py
# calculate_weight.py   Countss			       Solution_01.ipynb
# CalcWeight	      Data_For_Analysis		       Station_Count
# CalcWeight-save       Description of Assignment.ipynb  Station_Count_save
# coding.py	      Eigen-by-Station.sh	       stations.pkl.gz
# CountCdf	      generate_data_for_analysis.py    Stations_Statistics.ipynb
# count_cdf.py	      map-year-temp.py		       Statistics.py
# CountCdf-save	      mr_boostrap.conf		       temp
# count_measurement.py  mrjob and EMR.ipynb	       test.py
# counts		      mr_weather.py		       weather_MRjob.ipynb
# Counts		      mr_word_freq_count.py	       weather_MRjob-with-utils.ipynb
# counts_cdf	      README.txt
# CountsCdf	      reduce-year-temp.py

# %%
# !python generate_data_for_analysis.py -r emr --emr-job-flow-id $job_flow_id hdfs:/weather/weather.csv --output-dir=s3://lojin/Weather/data_for_analysis.csv --no-output
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# Attempting to terminate job...
# Traceback (most recent call last):
#   File "generate_data_for_analysis.py", line 48, in <module>
#     MRWeather.run()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/job.py", line 494, in run
#     mr_job.execute()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/job.py", line 512, in execute
#     super(MRJob, self).execute()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/launch.py", line 147, in execute
#     self.run_job()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/launch.py", line 213, in run_job
#     self.stdout.flush()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/runner.py", line 614, in __exit__
#     self.cleanup()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/emr.py", line 1010, in cleanup
#     super(EMRJobRunner, self).cleanup(mode=mode)
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/runner.py", line 560, in cleanup
# ...
